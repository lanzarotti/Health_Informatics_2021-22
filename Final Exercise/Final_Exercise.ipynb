# %% [markdown]
# # Final Exercise
#
# - Complete this notebook following the instruction
# - Save it with your Surname_Name_StudentBadgeNumber and upload it https://upload.di.unimi.it/?id=3014
#
# - Students who intend to take the exam on the 30th of May, are expected to upload this notebook within the 27th of May
# - For all the others the deadline for the submission is the 20th of june

# %%
pip install xlrd==1.2.0
# Out:
# ...
#      |████████████████████████████████| 103 kB 5.2 MB/s
# ...
#   Attempting uninstall: xlrd
#     Found existing installation: xlrd 1.1.0
#     Uninstalling xlrd-1.1.0:
#       Successfully uninstalled xlrd-1.1.0
# ...

# %%
import pandas as pd
import os  
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## 1. Load the excel file "'prost_surg.xlsx'" and plot the column names

# %%
#TO DO

# %% [markdown]
# ## 2. Look into data
#
# Referring to the Weight (column "W"), print: min, max, range of weight, and the number samples

# %%
#TO DO

# %% [markdown]
# ## 3. Plot the Weight distribution using the histogram

# %%
#TO DO

# %% [markdown]
# ## 4. Compute the mean, variance, standard deviation, median and mode of Weights

# %%
# TO DO

# %% [markdown]
# ## 5. Compute the BMI for each patient, add it to the dataFrame, and plot its distribution
# Remember:
# $\text{BMI} = \frac{W}{H^2}$

# %%
# TO DO

# %% [markdown]
# ## 6. Insert in the datafrane a column corresponding to the label Joule_cat
#
# Remember: if Joule is greater than 100.000 Joule_cat is 1 else it's 0

# %%
# TO DO

# %% [markdown]
# # Insert in the dataFrame a column corresponding to the the BMI_cat of each sample according to the following rule:
# - A subject is Normal if his/her BMI is less than 25 (insert value 'N')
# - A subject is Overweight if his/her BMI is between 25 (included) and 30  (insert value 'OW')
# - A subject is Obese if his/her BMI is greater equal 30  (insert value 'Ob')

# %%
#TO DO

# %% [markdown]
# ## 7. Compute, print, and plot Quantiles (first, second, third)

# %%
# TO DO
# Out:
# The 1st quartile is 23.25
# The 2nd quartile is 25.27
# The 3rd quartile is 27.56

# %% [markdown]
# ## 8. Considering overweight and obese subjects only, how many subjects have joule >100000 and age <76 ? Extract from the dataframe this information and print it

# %%
#TO DO

# %% [markdown]
# ## 9. Calculate two distinct 95 percentile of age for either overweight or obese subjects

# %%
#TO DO

# %% [markdown]
# ## 9. Group all data by Age and aggregate columns computing the mean value

# %%
#TO DO

# %% [markdown]
# ## 10. Plot the scatterplot to investigate possible dependencies between:
# - W and BMI
# - W and VolToT
# - W and FlowMax0
# - Tot30 and BMI

# %%
#TO DO

# %% [markdown]
# ## 11. Make an exhaustive correlation analysis.

# %%
#TO DO

# %% [markdown]
# ## 12. Compute and Plot the linear regression between W and BMI

# %%
#TO DO
