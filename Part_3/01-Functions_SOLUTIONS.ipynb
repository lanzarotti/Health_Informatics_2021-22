# %% [markdown]
# # <font color="blue">Functions</font>
#
#
# ## <font color="blue">Introduction to Functions</font>
#
#
# This lecture will consist of explaining what a function is in Python and how to create one. Functions will be one of our main building blocks when we construct larger and larger amounts of code to solve problems.
#
# **So what is a function?**
#
# Formally, a function is a useful device that groups together a set of statements so they can be run more than once. They can also let us specify parameters that can serve as inputs to the functions.
#
# On a more fundamental level, functions allow us to not have to repeatedly write the same code again and again. If you remember back to the lessons on strings and lists, remember that we used a function len() to get the length of a string. Since checking the length of a sequence is a common task you would want to write a function that can do this repeatedly at command.
#
# Functions will be one of most basic levels of reusing code in Python, and it will also allow us to start thinking of program design.

# %% [markdown]
# ## <font color="blue">def Statements</font>
#
#
# Let's see how to build out a function's syntax in Python. It has the following form:

# %%
def name_of_function(arg1,arg2):
    '''
    This is where the function's Document String (docstring) goes
    '''
    # Do stuff here
    # Return desired result

# %% [markdown]
# We begin with <code>def</code> then a space followed by the name of the function. Try to keep names relevant, for example len() is a good name for a length() function. Also be careful with names, you wouldn't want to call a function the same name as a [built-in function in Python](https://docs.python.org/2/library/functions.html) (such as len).
#
# Next come a pair of parentheses with a number of arguments separated by a comma. These arguments are the inputs for your function. You'll be able to use these inputs in your function and reference them. After this you put a colon.
#
# Now here is the important step, you must indent to begin the code inside your function correctly. Python makes use of *whitespace* to organize code. Lots of other programing languages do not do this, so keep that in mind.
#
# Next you'll see the docstring, this is where you write a basic description of the function. Using iPython and iPython Notebooks, you'll be able to read these docstrings by pressing Shift+Tab after a function name. Docstrings are not necessary for simple functions, but it's good practice to put them in so you or other people can easily understand the code you write.
#
# After all this you begin writing the code you wish to execute.
#
# The best way to learn functions is by going through examples. So let's try to go through examples that relate back to the various objects and data structures we learned about before.

# %% [markdown]
# ### <font color="blue">Example 1: A simple print 'hello' function</font>

# %%
def say_hello():
    print('hello')

# %% [markdown]
# Call the function:

# %%
say_hello()
# Out:
# hello

# %% [markdown]
# ### <font color="blue">Example 2: A simple greeting function</font>
#
# Let's write a function that greets people with their name.

# %%
def greeting(name):
    print('Hello %s' %(name))

# %%
greeting('John')
greeting('Sue')
# Out:
# Hello John
# Hello Sue

# %% [markdown]
# # <font color="red">EXERCISE 1</font>
#
# **Write a function that checks and print whether a number 'num' is in a given range '[low, high]' (inclusive of low and high)**

# %%
#TO DO
def range_check(num, low, high):
  if num >= low and num <= high:
    print("%d is in the range between %d and %d" % (num, low, high))
  else:
    print("%d is not in the range between %d and %d" % (num, low, high))

# %%
# Call the range_Check function

range_check(5, 2, 7)
# Out:
# 5 is in the range between 2 and 7

# %% [markdown]
# ## <font color="blue">Using return</font>
#
# Let's see some example that use a <code>return</code> statement. <code>return</code> allows a function to *return* a result that can then be stored as a variable, or used in whatever manner a user wants.
#
# ### <font color="blue">Example 3: Addition function</font>

# %%
def add_num(num1,num2):
  sum = num1 + num2
  return sum


#OR:
def add_num2(num1,num2):
  return num1 + num2

# %%
add_num(4,5)
# Out:
# 9

# %%
# Can also save as variable due to return
result = add_num(4,5)

# %%
print(result)
# Out:
# 9

# %% [markdown]
# What happens if we input two strings?

# %%
add_num('one','two')
# Out:
# 'onetwo'

# %% [markdown]
# Note that because we don't declare variable types in Python, this function could be used to add numbers or sequences together! We'll later learn about adding in checks to make sure a user puts in the correct arguments into a function.
#
# Let's also start using <code>break</code>, <code>continue</code>, and <code>pass</code> statements in our code. We introduced these during the <code>while</code> lecture.

# %% [markdown]
# Finally let's go over a full example of creating a function to check if a number is prime (a common interview exercise).
#
# We know a number is prime if that number is only evenly divisible by 1 and itself. Let's write our first version of the function to check all the numbers from 1 to N and perform modulo checks.

# %%
def is_prime(val):
    '''
    Naive method of checking for primes. 
    '''
    for num in range(2,val):
        if val % num == 0:
            return False
    else: # If never mod zero, then prime
        return True

# %%
n = 16 #try n = 17
if is_prime(n):
  print(n,'is  prime')
else:
  print(n,'is not prime')
# Out:
# 16 is not prime

# %% [markdown]
# Note how the <code>else</code> lines up under <code>for</code> and not <code>if</code>. This is because we want the <code>for</code> loop to exhaust all possibilities in the range before printing our number is prime.
#
# Also note how the return breaks the code as soon as we determine that a number is not prime.
#
# ## SOLUTION 2 (OPT)
# We can actually improve this function by only checking to the square root of the target number, and by disregarding all even numbers after checking for 2. We'll also switch to returning a boolean value to get an example of using return statements:

# %%
#SOLUTION 2 (OPT)

import math

def is_prime2(num):
    '''
    Better method of checking for primes. 
    '''
    if num % 2 == 0 and num > 2: 
        return False
    for i in range(3, int(math.sqrt(num)) + 1, 2):
        if num % i == 0:
            return False
    return True

# %%
is_prime2(18)
# Out:
# False

# %% [markdown]
# Why don't we have any <code>break</code> statements? It should be noted that as soon as a function *returns* something, it shuts down. A function can deliver multiple print statements, but it will only obey one <code>return</code>.

# %% [markdown]
# # <font color="red">EXERCISE 2</font>
#
# Great! You should now have a basic understanding of creating your own functions to save yourself from repeatedly writing code!

# %% [markdown]
# **Write a function that computes the volume of a sphere given its radius.**
# <p>The volume of a sphere is given as $$\frac{4}{3} πr^3$$</p>

# %%
#TO DO
def vol(rad):
    return 4/3*3.14*rad**3

#compute the volume
radius = 2 #cm
V =  vol(2)

# %% [markdown]
# # <font color="red">QUESTION</font>
#
# **Why should we implement a function rather than writing the corresponding code in our main script?**

# %% [markdown]
# __Answer:
#
# the function facilitate the **reuse** of code
#
# For example, I can use the volume of the sphere either to check if it respect some limit (application 1), or compute it's weight given its material (application 2). **Both need the volume of the sphere and delegate this computation to the funcioon `vol`**

# %%
#Application 1: 
maxVol = 30 #cm^3
radius = 2 #cm
V =  vol(radius)

if V >= maxVol:
  print('The volume %.1f  is too large' % V)
# Out:
# The volume 33.5  is too large

# %%
#Application 2:

# Specific weights:
sw_iron = 7.874 # g/cm³
sw_glass = 2.5  # g/cm³

r = 3 #radius
V = vol(r)
m  = input("Choose the sphere material between 'iron', and 'glass: ")
# Out:
# Choose the sphere material between 'iron', and 'glassglass

# %%
#SOL 1:

if m == 'iron':
  w = V* sw_iron 
else:  
  w = V* sw_glass

print("The sphere or radius %.1f cm,  volume %.1f cm^3, and material %r weighs %.1f g" % (r, V, m, w))
# Out:
# The sphere or radius 3.0 cm,  volume 113.0 cm^3, and material 'iron' weighs 890.1 g

# %%
#SOL 2  (manage possible errors:)

# Specific weights:
sw_iron = 7.874 # g/cm³
sw_glass = 2.5  # g/cm³

r = 3 #radius
V = vol(r)
m  = input("Choose the sphere material between 'iron', and 'glass: ")

err = 0
if m == 'iron':
  w = V* sw_iron 
elif m == 'glass':
  w = V* sw_glass
else:
  print("%r is an unknown material!" % m)
  err = 1

if err == 0:
  print("The sphere or radius %.1f cm,  volume %.1f cm^3, and material %r weighs %.1f g" % (r, V, m, w))
# Out:
# Choose the sphere material between 'iron', and 'glass: iron
# The sphere or radius 3.0 cm ,  volume 113.0 cm^3, and material 'iron' weighs 890.1 g

# %% [markdown]
# # <font color="red">EXERCISE 3</font>
#
# **Write a Python function to multiply all the numbers in a list.**
#
#     Sample List : [1, 2, 3, -4]
#     Expected Output : -24

# %%
def multiply(numbers):
    res = 1
    for number in numbers:
        res = res * number
    return res

m = multiply([1,2,-3, 5, 24])
print(m)
# Out:
# -720

# %% [markdown]
# # <font color="red">EXERCISE 4</font>
#
# **Write a function that accepts two parameters; the first is a list of numbers representing temperature, the second is the optional parameter `to_fahrenheit` which is set default to True. If `to_fahrenheit` is set to `True`, all the temperatures in the first parameters must be convertet to Fahrenheit using the formula $\frac{9}{5}*T + 32$ where $T$ is a temperature value in °C. If the second parameter is set to `False` all the temperatures in the first parameters must be convertet to Celsius using the formula $\frac{5}{9}*\big(T-32\big)$ where $T$ is a temperature value in °F**

# %%
def convert_temp(temperatures, to_fahrenheit=True):
    if to_fahrenheit:
      f = []
      for t in temperatures:
        f.append((float(9)/5)*t + 32)
      return f
    else:
      c = []
      for t in temperatures:
        c.append((float(5)/9)*(t-32))
      return c

celsius = [39.2, 36.5, 37.3, 37.8]
fahrenheit = convert_temp(celsius)

print('Temperatures in Celsius: %r' % celsius)
print('Temperatures in Fahrenheit: %r' % fahrenheit)

celsius_back = convert_temp(fahrenheit, to_fahrenheit=False)
print('Temperatures back in Celsius: %r ' % celsius_back)
# Out:
# Temperatures in Celsius: [39.2, 36.5, 37.3, 37.8]
# Temperatures in Fahrenheit: [102.56, 97.7, 99.14, 100.03999999999999]
# Temperatures back in Celsius: [39.2, 36.5, 37.300000000000004, 37.8]
