# %% [markdown]
# # Climbing Mount Rainier
#
# Here we will consider a climbing records dataset that shows the attempts and successes at reach the summit of the **Mount Rainier**, located 59 miles (95 km) south-southeast of **Seattle** with a summit elevation of 14,411 ft (**4,392 m**).
#
# This dataset is in a CSV file, and the function we're going to use to read in the file is called `read_csv()`.

# %%
from google.colab import drive
drive.mount('/gdrive')
# %cd /gdrive

base_dir = '/gdrive/My Drive/Colab_Notebooks/Health_Informatics/Part_4/data'
# Out:
# Mounted at /gdrive
# /gdrive

# %%
import pandas as pd
import os  
import matplotlib.pyplot as plt

df = pd.read_csv(os.path.join(base_dir, 'climbing_statistics.csv')) #it's a DataFrame
print(df.columns) #The column labels of the DataFrame.
# Out:
# Index(['Date', 'Route', 'Attempted', 'Succeeded', 'Success Percentage'], dtype='object')

# %% [markdown]
# ## EX 1: Look into data
#
# **Extract the `Attempted` column and print
# - the nb. of samples
# - the max nb. of attempted
# - the min nb. of attempted
# - the range between the max and min nb. of attempted**

# %%
#TO DO

# %% [markdown]
# ##Ex 2: sum up the information:
#
# **Referring to the Attempted, compute (using the function value_count), print and plot (the histogram) its distributuion**

# %%
#TO DO

# %% [markdown]
# ## Ex 3 Referring to the Attempted, print the mean, median and mode, compute the quantiles and plot them

# %%
#TO DO
